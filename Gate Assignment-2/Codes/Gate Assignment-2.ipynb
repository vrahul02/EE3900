# %%
import numpy as np
import math
import matplotlib.pyplot as plot

n = np.arange(0, 10, 1);
amplitude = np.sin(5/6*math.pi*time)
plot.plot(time, amplitude)

plot.title('$x(n)=1$')
plot.xlabel('n')
plot.ylabel('$y(n)$')

plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plot

n = np.arange(0, 10, 1);
amplitude = n*np.sin(5/6*math.pi*time)
plot.plot(time, amplitude)

plot.title('$x(n)=n$')
plot.xlabel('n')
plot.ylabel('$y(n)$')

plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()
